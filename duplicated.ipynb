# %%
import pandas as pd

# %%
df = pd.read_csv("suzuki_parts.csv")
df
# Out:
#                                            name             type_number  \
# 0       SUPERSEDED BY 0924714036 PLUG,OIL DRAIN      09247-14019 SUZUKI
# 1      SUPERSEDED BY 0924810008 PLUG,DRAIN,10X7      09248-10003 SUZUKI
# 2                                      TDC PLUG      09248-14011 SUZUKI
# 3                                          BOLT      09116-06096 SUZUKI
# 4                                          BOLT      09116-06121 SUZUKI
# ...                                         ...                     ...
# 65629  SUPERSEDED BY 1123541F00 UNION,CYL INLET      11235-38A01 SUZUKI
# 65630                           COVER COMP,SIDE  94420-25L10-QVP SUZUKI
# 65631                COVER,SIDE COWL RH (WHITE)  94420-28K00-YWW SUZUKI
# 65632                                SIDE COVER  94420-28K10-QEB SUZUKI
# 65633                        SIDE COWLING COVER  94420-28K30-YWW SUZUKI
#
#         price
# 0        5.60
# 1        5.89
# 2        2.92
# 3        2.26
# 4        2.72
# ...

# %%
duplicated = df[df.duplicated]
duplicated
# Out:
#                                                 name             type_number  \
# 3168                        BRAKE LAMP SWITCH SPRING      09443-06005 SUZUKI
# 3169                                          SPRING      09443-06046 SUZUKI
# 3170                                          SPRING      09443-06073 SUZUKI
# 3171                 SUPERSEDED BY 5721121H01 GRIP,L      57211-21H00 SUZUKI
# 3172                                          SPRING      09443-08001 SUZUKI
# ...                                              ...                     ...
# 65603                                 MANUAL, OWNERS  99011-49H56-03A SUZUKI
# 65604  ECSTAR R5000 10W40 MINERAL OIL 55 GALLON DRUM  990A0-01E10-55G SUZUKI
# 65605                             NLA799995018153LRG  99950-18153-LRG SUZUKI
# 65623                            NLA 799995015002XXL  99950-15002-XXL SUZUKI
# 65624                             NLA799995016322LRG  99950-16322-LRG SUZUKI
#
#          price
# 3168      3.31
# ...

# %%
duplicated.to_csv("duplicated.csv", index=False)
